# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/YoloV8')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# image_classification.ipynb  images  runs  yolov8l-cls.pt

# %% [markdown]
# **Install ultralytics**

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 685.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.6/871.6 kB 875.7 kB/s eta 0:00:00
# ...

# %% [markdown]
# Import ultralytics

# %%
from ultralytics import YOLO

# %%
# !ls
# Out:
# image_classification.ipynb  images  runs  yolov8l-cls.pt

# %%
# Load a pretrained YOLOv8n model
model = YOLO('yolov8l-cls.pt')  # load a pretrained model (recommended for training)

# %%
# Train the model
results = model.train(data='images/data_1/', epochs=30)
# Out:
# Ultralytics YOLOv8.2.93 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# **Export the model to ONNX**

# %%
# Export the model to ONNX
model.export(format="onnx")
# Out:
# Ultralytics YOLOv8.2.93 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8l-cls summary (fused): 133 layers, 36,187,138 parameters, 0 gradients, 98.7 GFLOPs
#
# PyTorch: starting from 'runs/classify/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 2) (69.2 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 5.4 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.1s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.16.2 opset 19...
# ONNX: export success ✅ 10.2s, saved as 'runs/classify/train3/weights/best.onnx' (138.1 MB)
#
# Export complete (12.7s)
# Results saved to /content/drive/MyDrive/YoloV8/runs/classify/train3/weights
# ...

# %%
model = YOLO('runs/classify/train4/weights/best.pt')

# %%
# Predict
results = model.predict(source="images/data_1/predict/01.jpg", save=True, imgsz=640,conf=0.5)
# results
# Out:
# image 1/1 /content/drive/MyDrive/YoloV8/images/data_1/predict/01.jpg: 224x224 ng 0.68, ok 0.32, 7.8ms
# Speed: 16.4ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict3
