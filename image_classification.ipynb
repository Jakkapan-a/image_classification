# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/MGD')

# %%
# prompt: YoloV8 use train custon image classification

# !pip install ultralytics

from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data='path/to/your/dataset.yaml', epochs=100)  # train the model

# Validate the model
results = model.val()

# Predict with the model
results = model.predict(source='path/to/your/image.jpg', save=True)

# Export the model
model.export(format='onnx')
